# %%
from casalib.known_names import NamesManager

# %%
t = NamesManager(name='KnownNames', file='known_tables')

# %%
t['esposa'] = 'Driele'
t['eu'] = 'Paulo'

# %%
t.full
# Out:
# {'esposa': 'Driele',
#  'eu': 'Paulo',
#  'sample___esposa': '\nwith\ninput_ as (\n    select * from Driele\n    limit 100\n)\nselect * from input_\n',
#  'sample___eu': '\nwith\ninput_ as (\n    select * from Paulo\n    limit 100\n)\nselect * from input_\n',
#  'select___esposa': 'select * from Driele',
#  'select___eu': 'select * from Paulo',
#  'select_max___esposa': '\nwith\ninput_ as (\n    select * from Driele\n)\n,\npart_ as (\n    select * from input_\n    where\n        dt_ingestao =\n        (select max(dt_ingestao) from input_)\n)\nselect * from part_\n',
#  'select_max___eu': '\nwith\ninput_ as (\n    select * from Paulo\n)\n,\npart_ as (\n    select * from input_\n    where\n        dt_ingestao =\n        (select max(dt_ingestao) from input_)\n)\nselect * from part_\n'}

# %%
t['temp']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 t['temp']
#
# File ~/WS/casalib/src/casalib/known_names/_base.py:81, in NamesManager.__getitem__(self, key)
#      79 def __getitem__(self, key: str) -> str:
#      80     """ Get the info """
# ---> 81     return self.get_info_(key)
#
# File ~/WS/casalib/src/casalib/known_names/_base.py:117, in NamesManager.get_info_(self, key)
#     114 if res is not None:
#     115     return res
# --> 117 raise ValueError(
#     118     f'Key not found: {key}. '
#     119     f'Known keys: {list(self.dict_names)}. '
#     120     f'Known functions: {list(self.full)}'
#     121 )
#
# ValueError: Key not found: temp. Known keys: ['esposa', 'eu']. Known functions: ['esposa', 'eu', 'sample___esposa', 'sample___eu', 'select___esposa', 'select___eu', 'select_max___esposa', 'select_max___eu']
